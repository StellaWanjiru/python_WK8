# %%
import pandas as pd
data=pd.read_csv('owid-covid-data.csv')
print(data)
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1          AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 47518      EST    Europe      Estonia  2021-03-07      75003.0     1319.0
# 47519      EST    Europe      Estonia  2021-03-08      76183.0     1180.0
# 47520      EST    Europe      Estonia  2021-03-09      77491.0     1308.0
# 47521      EST    Europe      Estonia  2021-03-10      78973.0     1482.0
# 47522      EST    Europe      Estonia  2021-03-11      80929.0     1956.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 47518            1343.286         653.0         9.0                9.143  ...
# 47519            1365.000         667.0        14.0                9.857  ...
# 47520            1393.143         669.0         2.0                9.143  ...
# 47521            1397.143         677.0         8.0                8.857  ...
# 47522            1474.143         686.0         9.0                9.000  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 0                 NaN           NaN                  37.746
# 1                 NaN           NaN                  37.746
# 2                 NaN           NaN                  37.746
# 3                 NaN           NaN                  37.746
# 4                 NaN           NaN                  37.746
# ...               ...           ...                     ...
# 47518            24.5          39.3                     NaN
# 47519            24.5          39.3                     NaN
# 47520            24.5          39.3                     NaN
# 47521            24.5          39.3                     NaN
# 47522             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                            0.50            64.83                    0.511
# 1                            0.50            64.83                    0.511
# 2                            0.50            64.83                    0.511
# 3                            0.50            64.83                    0.511
# 4                            0.50            64.83                    0.511
# ...                           ...              ...                      ...
# 47518                        4.69            78.74                    0.892
# 47519                        4.69            78.74                    0.892
# 47520                        4.69            78.74                    0.892
# 47521                        4.69            78.74                    0.892
# 47522                         NaN              NaN                      NaN
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                       NaN                          NaN
# 1                                       NaN                          NaN
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
# 4                                       NaN                          NaN
# ...                                     ...                          ...
# 47518                                 530.0                         2.79
# 47519                                   NaN                          NaN
# 47520                                   NaN                          NaN
# 47521                                   NaN                          NaN
# 47522                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 0                   NaN                                      NaN
# 1                   NaN                                      NaN
# 2                   NaN                                      NaN
# 3                   NaN                                      NaN
# 4                   NaN                                      NaN
# ...                 ...                                      ...
# 47518             24.82                               399.943253
# 47519               NaN                                      NaN
# 47520               NaN                                      NaN
# 47521               NaN                                      NaN
# 47522               NaN                                      NaN
#
# [47523 rows x 67 columns]

# %%
#✅ Analyze time trends (cases, deaths, vaccinations)
data['total_cases'].value_counts()
# Out:
# total_cases
# 1.0        438
# 3.0        368
# 2.0        197
# 18.0       191
# 141.0      137
#           ...
# 40975.0      1
# 41330.0      1
# 41966.0      1
# 42656.0      1
# 43343.0      1
# Name: count, Length: 29300, dtype: int64

# %%
#Compare metrics across countries/regions
data['location'].value_counts()
# Out:
# location
# Argentina                          795
# Asia                               774
# China                              774
# Canada                             773
# Australia                          770
#                                   ...
# Burundi                            705
# Bonaire Sint Eustatius and Saba    703
# Comoros                            675
# Estonia                            403
# Cook Islands                       289
# Name: count, Length: 66, dtype: int64

# %%
graphs = data.value_counts('location')
graphs.plot.bar()
# Out:
# <Axes: xlabel='location'>
